# %% [markdown]
# # Capstone Project- The Battle of the Neighborhoods

# %%
# Importing packages
print('Importing libraries...')
import numpy as np
import pandas as pd
import json
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
import requests 
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
import folium
print('Libraries imported! :D')
# Out:
# Importing libraries...
# Libraries imported! :D

# %%
#Importing cities dataset
# !wget -q -O 'cities.csv' https://public.opendatasoft.com/explore/dataset/1000-largest-us-cities-by-population-with-geographic-coordinates/download/?format=csv&timezone=Asia/Shanghai&lang=en&use_labels_for_header=true&csv_separator=%3B
print('Data downloaded!')
# Out:
# Data downloaded!

# %%
with open('cities.csv') as cities_data:
    cities= pd.read_csv(cities_data, sep=';')
cities.head(5)
# Out:
#          City  Rank           State  Growth From 2000 to 2013  Population  \
# 0  Marysville   552      Washington                     115.7       63269
# 1      Perris   466      California                      98.7       72326
# 2   Cleveland    48            Ohio                     -18.1      390113
# 3   Worcester   129   Massachusetts                       5.8      182544
# 4    Columbia   192  South Carolina                      11.7      133358
#
#                Coordinates
# 0  48.0517637,-122.1770818
# 1  33.7825194,-117.2286478
# 2     41.49932,-81.6943605
# 3   42.2625932,-71.8022934
# 4   34.0007104,-81.0348144

# %%
#Splitting Coordinates column
lat = []
lon = []

# For each row in a varible,
for row in cities['Coordinates']:
    # Try to,
    try:
        # Split the row by comma and append
        # everything before the comma to lat
        lat.append(row.split(',')[0])
        # Split the row by comma and append
        # everything after the comma to lon
        lon.append(row.split(',')[1])
    # But if you get an error
    except:
        # append a missing value to lat
        lat.append(np.NaN)
        # append a missing value to lon
        lon.append(np.NaN)

# Create two new columns from lat and lon
cities['latitude'] = lat
cities['longitude'] = lon

cities.head(5)
# Out:
#          City  Rank           State  Growth From 2000 to 2013  Population  \
# 0  Marysville   552      Washington                     115.7       63269
# 1      Perris   466      California                      98.7       72326
# 2   Cleveland    48            Ohio                     -18.1      390113
# 3   Worcester   129   Massachusetts                       5.8      182544
# 4    Columbia   192  South Carolina                      11.7      133358
#
#                Coordinates    latitude     longitude
# 0  48.0517637,-122.1770818  48.0517637  -122.1770818
# 1  33.7825194,-117.2286478  33.7825194  -117.2286478
# 2     41.49932,-81.6943605    41.49932   -81.6943605
# 3   42.2625932,-71.8022934  42.2625932   -71.8022934
# 4   34.0007104,-81.0348144  34.0007104   -81.0348144

# %%
#Selecting relevent columns
cities.drop(['Rank', 'Growth From 2000 to 2013', 'Coordinates'], axis= 1, inplace= True)
cities
# Out:
#               City           State  Population    latitude     longitude
# 0       Marysville      Washington       63269  48.0517637  -122.1770818
# 1           Perris      California       72326  33.7825194  -117.2286478
# 2        Cleveland            Ohio      390113    41.49932   -81.6943605
# 3        Worcester   Massachusetts      182544  42.2625932   -71.8022934
# 4         Columbia  South Carolina      133358  34.0007104   -81.0348144
# ..             ...             ...         ...         ...           ...
# 995  Santa Barbara      California       90412  34.4208305  -119.6981901
# 996        Addison        Illinois       37385   41.931696   -87.9889556
# 997     Rio Rancho      New Mexico       91956  35.2327544  -106.6630437
# 998         Normal        Illinois       54664  40.5142026   -88.9906312
# 999     Romeoville        Illinois       39650  41.6475306   -88.0895061
#
# [1000 rows x 5 columns]

# %%
#Checking data cleaning- Removing NAs and Duplicates
display(cities.isnull().any())
print('Are any rows duplicated? ' + str(cities.duplicated().any()))
# Out:
# City          False
# State         False
# Population    False
# latitude      False
# longitude     False
# dtype: bool
# Are any rows duplicated? False

# %%
#Checking Central location for United States
address = 'United States of America'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of U.S. are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of U.S. are 39.7837304, -100.4458825.

# %%
#Creating map showing all cities in consideration
map_us = folium.Map(location=[latitude, longitude], zoom_start=3)

# add markers to map
for lat, lng, city, state in zip(cities['latitude'], cities['longitude'], cities['City'], cities['State']):
    label = '{}, {}'.format(city, state)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_us)  
    
map_us
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Defining Foursquare Credentials
CLIENT_ID = 'S5CN3L51JZBRUYZVXCMZQOSAMNPOFYXY30PH32JLV0MK5SXT' # your Foursquare ID
CLIENT_SECRET = 'ENVGYBCT5JOAPJH2DD4LQD0ZIOZQYP3TPTUIYSBPYA4OFAU0' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: S5CN3L51JZBRUYZVXCMZQOSAMNPOFYXY30PH32JLV0MK5SXT
# CLIENT_SECRET:ENVGYBCT5JOAPJH2DD4LQD0ZIOZQYP3TPTUIYSBPYA4OFAU0

# %%
#Defining function that will get all the services 
def getNearbyVenues(names, latitudes, longitudes, radius=25000, LIMIT=2000):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        try:
            results = requests.get(url).json()["response"]['groups'][0]['items']
        except KeyError:
            results= [np.nan, np.nan, np.nan, np.nan]
        
        # return only relevant information for each nearby venue
        try:
            venues_list.append([(
                name, 
                lat, 
                lng, 
                v['venue']['name'], 
                v['venue']['location']['lat'], 
                v['venue']['location']['lng'],  
                v['venue']['categories'][0]['name']) for v in results])
        except TypeError: 
            venues_list.append([(
            np.nan, np.nan, np.nan,np.nan,np.nan,np.nan,np.nan,)])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['City', 
                  'City Latitude', 
                  'City Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
us_venues = getNearbyVenues(names=cities['City'],
                                   latitudes=cities['latitude'],
                                   longitudes=cities['longitude'])
# Out:
# Marysville
# Perris
# Cleveland
# Worcester
# Columbia
# Waterbury
# Eagan
# Southfield
# Lafayette
# Boise City
# Elkhart
# Buena Park
# Marietta
# Parker
# West Palm Beach
# Salem
# Aurora
# Leesburg
# Doral
# Westminster
# Lubbock
# Overland Park
# Jackson
# Gastonia
# Daytona Beach
# Kansas City
# Noblesville
# Southaven
# Chino
# Gaithersburg
# Fountain Valley
# Frederick
# Greenville
# DeKalb
# West Allis
# Thornton
# West Des Moines
# Fall River
# Tulare
# Chula Vista
# Coral Springs
# Concord
# Smyrna
# Apopka
# Grand Forks
# Lancaster
# Naperville
# Hollywood
# Rogers
# New Orleans
# Lakewood
# Oak Lawn
# Caldwell
# Portland
# Concord
# Burien
# St. Charles
# Waukesha
# Flagstaff
# Puyallup
# Schenectady
# Denver
# Springfield
# Campbell
# Moreno Valley
# Kettering
# Lincoln Park
# Lake Havasu City
# North Little Rock
# Reno
# Littleton
# Prescott
# Dublin
# Texarkana
# Portland
# Brooklyn Park
# West Haven
# El Centro
# The Colony
# Flint
# Pittsburg
# Buckeye
# Brea
# Indio
# Scottsdale
# Columbus
# Lancaster
# Lincoln
# Trenton
# Boston
# Glendora
# Rochester
# Florissant
# Annapolis
# Chapel Hill
# Lawrence
# Calexico
# Calumet City
# Missoula
# Clovis
# Pearland
# Gilbert
# Wausau
# Raleigh
# Orange
# Walnut Creek
# Bremerton
# Porterville
# Marana
# Tallahassee
# Conroe
# Blacksburg
# San Antonio
# Hartford
# Waterloo
# Binghamton
# Meridian
# Fond du Lac
# Baytown
# Cary
# Weymouth Town
# Tulsa
# Mission
# 0              NaN             NaN
# 1              NaN             NaN
# 2              NaN             NaN
# 3              NaN             NaN
# 4              NaN             NaN

# %%
#removing na values from dataframe
us_venues.dropna(axis=0, inplace=True)
print(us_venues.shape)
us_venues.head()
# Out:
# (0, 7)
# Empty DataFrame
# Columns: [City, City Latitude, City Longitude, Venue, Venue Latitude, Venue Longitude, Venue Category]
# Index: []

# %%
#Looking at counts per city
us_venues.groupby('City').count().head()
# Out:
# Empty DataFrame
# Columns: [City Latitude, City Longitude, Venue, Venue Latitude, Venue Longitude, Venue Category]
# Index: []

# %%
#How many unique categories
print('There are {} uniques categories.'.format(len(us_venues['Venue Category'].unique())))
# Out:
# There are 0 uniques categories.

# %%
# one hot encoding
us_onehot = pd.get_dummies(us_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
us_onehot['City'] = us_venues['City'] 

# move neighborhood column to the first column
fixed_columns = [us_onehot.columns[-1]] + list(us_onehot.columns[:-1])
us_onehot = us_onehot[fixed_columns]

us_onehot.head()
# Out:
# Empty DataFrame
# Columns: [City, Venue Category]
# Index: []

# %%
#Fixing Columns
us_onehot=us_onehot.set_index('City')
us_onehot
# Out:
# Empty DataFrame
# Columns: [Venue Category]
# Index: []

# %%
#Grouped by city
us_grouped = us_onehot.groupby('City').mean().reset_index()
us_grouped
# Out:
# Empty DataFrame
# Columns: [City, Venue Category]
# Index: []

# %%
#Function for most popular venue types per city
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['City']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
city_venues_sorted = pd.DataFrame(columns=columns)
city_venues_sorted['City'] = us_grouped['City']

for ind in np.arange(us_grouped.shape[0]):
    city_venues_sorted.iloc[ind, 1:] = return_most_common_venues(us_grouped.iloc[ind, :], num_top_venues)

city_venues_sorted.head()
# Out:
# Empty DataFrame
# Columns: [City, 1st Most Common Venue, 2nd Most Common Venue, 3rd Most Common Venue, 4th Most Common Venue, 5th Most Common Venue, 6th Most Common Venue, 7th Most Common Venue, 8th Most Common Venue, 9th Most Common Venue, 10th Most Common Venue]
# Index: []

# %%
#K means clustering to visualize
# set number of clusters
kclusters = 10

us_grouped_clustering = us_grouped.drop('City', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(us_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-158-8def17672da5> in <module>
#       6
#       7 # run k-means clustering
# ----> 8 kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(us_grouped_clustering)
#       9
#      10 # check cluster labels generated for each row in the dataframe
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/cluster/_kmeans.py in fit(self, X, y, sample_weight)
#     857         order = "C" if self.copy_x else None
#     858         X = check_array(X, accept_sparse='csr', dtype=[np.float64, np.float32],
# --> 859                         order=order, copy=self.copy_x)
#     860         # verify that the number of samples given is larger than k
#     861         if _num_samples(X) < self.n_clusters:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     584                              " minimum of %d is required%s."
#     585                              % (n_samples, array.shape, ensure_min_samples,
# --> 586                                 context))
#     587
#     588     if ensure_min_features > 0 and array.ndim == 2:
#
# ValueError: Found array with 0 sample(s) (shape=(0, 1)) while a minimum of 1 is required.

# %%
# add clustering labels
city_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

city_merged = cities

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
city_merged = city_merged.join(city_venues_sorted.set_index('City'), on='City')

city_merged.dropna(axis=0, inplace=True)
city_merged['Cluster Labels']= city_merged['Cluster Labels'].astype(int)

city_merged.head() # check the last columns!

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=3)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(city_merged['latitude'], city_merged['longitude'], city_merged['City'], city_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters

# %%
user_reftable=us_grouped

# %%
#defining user needed data

c_name= input("What is your name? " )
imp= []
print('Please choose services from the following list: ')
data= list(user_reftable.columns)
chunks = [data[x:x+10] for x in range(0, len(data), 10)]
cat_table= pd.DataFrame(chunks)
display(cat_table)
for i in range(10):
    if i==0:
        p= input('What is the most important service? ')
    elif i==1:
        p= input('What is the ' + str(i+1) + 'nd most important service?')
    elif i==2:
        p= input('What is the ' + str(i+1) + 'rd most important service?')
    else:
        p= input('What is the ' + str(i+1) + 'th most important service?')
    imp.append(p)

print('Thank you for your input!')
# Out:
# What is your name? Avnika
# Please choose services from the following list:
#                                 0                        1  \
# 0                            City              Zoo Exhibit
# 1                  Airport Lounge          Airport Service
# 2                Arepa Restaurant   Argentinian Restaurant
# 3                 Auto Dealership              Auto Garage
# 4                Baseball Stadium         Basketball Court
# 5                        Beer Bar              Beer Garden
# 6                       Bookstore          Border Crossing
# 7                          Bridge          Bubble Tea Shop
# 8       Cajun / Creole Restaurant     Cambodian Restaurant
# 9                    Carpet Store                   Casino
# 10                         Cidery             Climbing Gym
# 11       College Basketball Court        College Bookstore
# 12         College Residence Hall          College Stadium
# 13              Convenience Store        Convention Center
# 14                   Dance Studio            Deli / Bodega
# 15                       Dive Bar          Doctor's Office
# 16              Electronics Store        Elementary School
# 17                        Factory                     Fair
# 18     Financial or Legal Service          Fireworks Store
# 19              Food & Drink Shop               Food Court
# 20             Frozen Yogurt Shop  Fruit & Vegetable Store
# 21          General Entertainment        German Restaurant
# 22        Grilled Meat Restaurant            Grocery Store
# 23                 Hardware Store      Hawaiian Restaurant
# 24                     Hobby Shop             Hockey Arena
# 25                      Hotel Bar        Hotpot Restaurant
# 26                            Inn            Internet Cafe
# 27                  Jewelry Store                Juice Bar
# 28            Leather Goods Store      Lebanese Restaurant
# 29           Marijuana Dispensary                   Market
# 30                    Men's Store       Mexican Restaurant
# 31           Mongolian Restaurant      Monument / Landmark
# 32                         Museum             Music School
# 33                 Nightlife Spot               Non-Profit
# 34           Other Great Outdoors          Other Nightlife
# 35  Paper / Office Supplies Store                     Park
# 36                      Pet Store                 Pharmacy
# 37                     Playground                    Plaza
# 38                        RV Park               Racecourse
# 39                 Rental Service                Reservoir
# 40                      Roof Deck       Russian Restaurant
# 41                 Shipping Store               Shoe Store
# 42                      Ski Lodge                Ski Trail
# 43      South American Restaurant  South Indian Restaurant
# 44                     Sports Bar              Sports Club
# 45                 Student Center              Summer Camp
# 46                    Tailor Shop     Taiwanese Restaurant
# 47                Thai Restaurant                  Theater
# 48                          Track             Trade School
# 49             Turkish Restaurant               University
# 50                       Vineyard                  Volcano
# 51                         Winery              Wings Joint
#
#                                            2                             3  \
# 0                                        ATM             Accessories Store
# 1                           Airport Terminal           American Restaurant
# 2                                Art Gallery                    Art Museum
# 3                              Auto Workshop               Automotive Shop
# 4                         Basketball Stadium                    Bath House
# 5                                 Beer Store            Belgian Restaurant
# 6                           Botanical Garden                      Boutique
# 7                                     Buffet                      Building
# 8                               Camera Store                    Campground
# 9                                     Castle                          Cave
# 10                            Clothing Store                    Club House
# 11                         College Cafeteria  College Engineering Building
# 12                           College Theater          Colombian Restaurant
# 13                            Cosmetics Shop                        County
# 14                          Department Store                 Design Studio
# 15                                   Dog Run            Donburi Restaurant
# 16                       Empanada Restaurant            English Restaurant
# 17                        Falafel Restaurant                          Farm
# 18                         Fish & Chips Shop                   Fish Market
# 19                              Food Service                    Food Stand
# 20                    Furniture / Home Store                   Gaming Cafe
# 21                                 Gift Shop        Gluten-free Restaurant
# 22                                 Gun Range                      Gun Shop
# 23                   Health & Beauty Service             Health Food Store
# 24                               Hockey Rink                  Home Service
# 25                          Hunan Restaurant                Hunting Supply
# 26                              Intersection                     Irish Pub
# 27                               Karaoke Bar                    Kids Store
# 28                                   Library                    Lighthouse
# 29                         Martial Arts Dojo                Massage Studio
# 30                           Meze Restaurant     Middle Eastern Restaurant
# 31                       Moroccan Restaurant                         Motel
# 32                               Music Store                   Music Venue
# 33                              Noodle House       North Indian Restaurant
# 34                         Other Repair Shop           Outdoor Event Space
# 35                                   Parking                   Pastry Shop
# 36                           Photography Lab            Photography Studio
# 37                                Poke Place             Polish Restaurant
# 38                                 Racetrack                 Radio Station
# 39  Residential Building (Apartment / Condo)                        Resort
# 40                               Salad Place            Salon / Barbershop
# 41                            Shop & Service                 Shopping Mall
# 42                       Skydiving Drop Zone                    Smoke Shop
# 43           Southern / Soul Food Restaurant                 Souvlaki Shop
# 44                                   Stables                       Stadium
# 45                               Supermarket               Supplement Shop
# 46                             Tanning Salon              Tapas Restaurant
# 47                                Theme Park  Theme Park Ride / Attraction
# 48                                     Trail                 Train Station
# 49                            Used Bookstore                    Vape Store
# 50                          Volleyball Court               Warehouse Store
# 51                             Women's Store                   Yoga Studio
#
#                                 4                        5  \
# 0                  Adult Boutique       Advertising Agency
# 1                    Amphitheater           Animal Shelter
# 2             Arts & Crafts Store         Asian Restaurant
# 3                       BBQ Joint               Bagel Shop
# 4                    Bathing Area      Bavarian Restaurant
# 5                   Big Box Store                Bike Shop
# 6                   Bowling Alley               Boxing Gym
# 7                    Burger Joint       Burmese Restaurant
# 8                           Canal               Canal Lock
# 9                        Cemetery              Cheese Shop
# 10                   Cocktail Bar              Coffee Shop
# 11         College Football Field              College Gym
# 12                    Comedy Club  Comfort Food Restaurant
# 13                Coworking Space             Credit Union
# 14                   Dessert Shop       Dim Sum Restaurant
# 15                     Donut Shop         Drive-in Theater
# 16           Ethiopian Restaurant            Event Service
# 17                 Farmers Market     Fast Food Restaurant
# 18                  Fishing Store              Flea Market
# 19                     Food Truck         Football Stadium
# 20                         Garden            Garden Center
# 21                  Go Kart Track              Golf Course
# 22                            Gym     Gym / Fitness Center
# 23           Herbs & Spices Store              High School
# 24                     Hookah Bar                 Hospital
# 25                    IT Services           Ice Cream Shop
# 26                         Island       Israeli Restaurant
# 27           Kitchen Supply Store        Korean Restaurant
# 28                 Lingerie Store             Liquor Store
# 29                 Mattress Store                  Meadery
# 30                  Military Base                Mini Golf
# 31                Motorcycle Shop         Motorsports Shop
# 32                     Nail Salon            National Park
# 33                   Nudist Beach              Observatory
# 34              Outdoor Sculpture     Outdoor Supply Store
# 35                      Pawn Shop         Pedestrian Plaza
# 36                       Pie Shop                     Pier
# 37                           Pool                Pool Hall
# 38                        Rafting         Ramen Restaurant
# 39                      Rest Area               Restaurant
# 40                 Sandwich Place           Scenic Lookout
# 41                 Shopping Plaza               Skate Park
# 42                  Smoothie Shop              Snack Place
# 43                            Spa       Spanish Restaurant
# 44        State / Provincial Park               Steakhouse
# 45                      Surf Spot         Sushi Restaurant
# 46                  Tattoo Parlor                 Tea Room
# 47               Theme Restaurant   Thrift / Vintage Store
# 48                   Tram Station        Trattoria/Osteria
# 49  Vegetarian / Vegan Restaurant    Venezuelan Restaurant
# 50                     Water Park                Waterfall
# 51                            Zoo                     None
#
#                                   6                          7  \
# 0                 Afghan Restaurant         African Restaurant
# 1                      Antique Shop              Apres Ski Bar
# 2                Athletics & Sports                 Auditorium
# 3                            Bakery                       Bank
# 4                               Bay                      Beach
# 5                        Bike Trail                     Bistro
# 6              Brazilian Restaurant             Breakfast Spot
# 7                     Burrito Place           Business Service
# 8                       Candy Store           Capitol Building
# 9                Chinese Restaurant             Chocolate Shop
# 10  College Administrative Building      College Arts Building
# 11              College Hockey Rink            College Library
# 12                       Comic Shop           Community Center
# 13                         Creperie           Cuban Restaurant
# 14                            Diner                  Disc Golf
# 15                        Drugstore        Dumpling Restaurant
# 16                      Event Space                    Exhibit
# 17                         Festival                      Field
# 18                  Floating Market                Flower Shop
# 19                           Forest                   Fountain
# 20                      Gas Station                  Gastropub
# 21               Golf Driving Range               Gourmet Shop
# 22                         Gym Pool             Gymnastics Gym
# 23                             Hill       Himalayan Restaurant
# 24                           Hostel              Hot Dog Joint
# 25                Indian Restaurant        Indie Movie Theater
# 26               Italian Restaurant  Japanese Curry Restaurant
# 27                             Lake                  Laser Tag
# 28                           Lounge              Luggage Store
# 29                   Medical Center             Medical School
# 30               Miscellaneous Shop          Mobile Phone Shop
# 31                         Mountain              Movie Theater
# 32                  Nature Preserve               Neighborhood
# 33                           Office                Opera House
# 34            Outdoors & Recreation                Outlet Mall
# 35            Performing Arts Venue         Persian Restaurant
# 36                  Piercing Parlor                Pizza Place
# 37            Portuguese Restaurant                 Print Shop
# 38                      Record Shop           Recording Studio
# 39                            River         Rock Climbing Spot
# 40                           School             Science Museum
# 41                     Skating Rink                   Ski Area
# 42                     Soccer Field             Soccer Stadium
# 43                        Speakeasy           Spiritual Center
# 44                 Storage Facility                Street Fair
# 45                      Swim School           Swiss Restaurant
# 46                           Temple               Tennis Court
# 47                         Tiki Bar              Tour Provider
# 48               Travel & Transport              Travel Agency
# 49                     Veterinarian           Video Game Store
# 50                       Waterfront                 Whisky Bar
# 51                             None                       None
#
#                              8                                9
# 0                      Airport               Airport Food Court
# 1                     Aquarium                           Arcade
# 2        Australian Restaurant              Austrian Restaurant
# 3                          Bar                   Baseball Field
# 4                    Beach Bar                  Bed & Breakfast
# 5                   Board Shop                    Boat or Ferry
# 6                      Brewery                      Bridal Shop
# 7                      Butcher                             Café
# 8                     Car Wash             Caribbean Restaurant
# 9                       Church                     Churrascaria
# 10          College Auditorium         College Baseball Diamond
# 11                College Quad               College Rec Center
# 12                Concert Hall       Construction & Landscaping
# 13                Cupcake Shop                     Cycle Studio
# 14              Discount Store                       Distillery
# 15            Dutch Restaurant      Eastern European Restaurant
# 16                  Eye Doctor                      Fabric Shop
# 17         Filipino Restaurant                      Film Studio
# 18           Fondue Restaurant                             Food
# 19           French Restaurant              Fried Chicken Joint
# 20                     Gay Bar     General College & University
# 21         Government Building                 Greek Restaurant
# 22            Halal Restaurant                  Harbor / Marina
# 23               Historic Site                   History Museum
# 24                  Hot Spring                            Hotel
# 25               Indie Theater                 Indoor Play Area
# 26         Japanese Restaurant                        Jazz Club
# 27   Latin American Restaurant                           Lawyer
# 28          Mac & Cheese Joint                 Malay Restaurant
# 29    Mediterranean Restaurant                    Memorial Site
# 30  Modern European Restaurant  Molecular Gastronomy Restaurant
# 31               Moving Target                        Multiplex
# 32     New American Restaurant                        Nightclub
# 33                Optical Shop                  Organic Grocery
# 34                Outlet Store             Pakistani Restaurant
# 35         Peruvian Restaurant                      Pet Service
# 36                 Planetarium                         Platform
# 37                         Pub                       Public Art
# 38           Recreation Center              Rental Car Location
# 39                   Rock Club              Romanian Restaurant
# 40            Sculpture Garden               Seafood Restaurant
# 41               Ski Chairlift                       Ski Chalet
# 42                 Social Club                       Soup Place
# 43              Sporting Event              Sporting Goods Shop
# 44       Street Food Gathering                       Strip Club
# 45         Szechuan Restaurant                       Taco Place
# 46              Tennis Stadium               Tex-Mex Restaurant
# 47  Tourist Information Center                 Toy / Game Store
# 48                        Tree                       Truck Stop
# 49                 Video Store            Vietnamese Restaurant
# 50                    Wine Bar                        Wine Shop
# 51                        None                             None
# What is the most important service? University
# What is the 2nd most important service?Coffee Shop
# What is the 3rd most important service?Store
# What is the 4th most important service?Waterfront
# What is the 5th most important service?Theme Park
# What is the 6th most important service?Water PArk
# What is the 7th most important service?School
# What is the 8th most important service?High School
# What is the 9th most important service?Train Station
# What is the 10th most important service?Trail
# Thank you for your input!

# %%
user_reftable= user_reftable.append({'City': c_name+"'s City"}, ignore_index=True)
user_row=user_reftable[user_reftable['City']==c_name+"'s City"].index[0]

# %%
user_reftable.set_index('City', inplace=True)
user_reftable
# Out:
#                Zoo Exhibit  ATM  Accessories Store  Adult Boutique  \
# City
# Avnika                 0.0  0.0                0.0            0.00
# Avnika                 0.0  0.0                0.0            0.00
# Avnika                 0.0  0.0                0.0            0.01
# Avnika                 0.0  0.0                0.0            0.00
# Avnika                 0.0  0.0                0.0            0.00
# ...                    ...  ...                ...             ...
# Avnika                 0.0  0.0                0.0            0.00
# Avnika                 0.0  0.0                0.0            0.00
# Avnika                 0.0  0.0                0.0            0.00
# Avnika                 0.0  0.0                0.0            0.00
# Avnika's City          NaN  NaN                NaN             NaN
#
#                Advertising Agency  Afghan Restaurant  African Restaurant  \
# City
# Avnika                        0.0                0.0                 0.0
# Avnika                        0.0                0.0                 0.0
# Avnika                        0.0                0.0                 0.0
# Avnika                        0.0                0.0                 0.0
# Avnika                        0.0                0.0                 0.0
# ...                           ...                ...                 ...
# Avnika                        0.0                0.0                 0.0
# Avnika                        0.0                0.0                 0.0
# Avnika                        0.0                0.0                 0.0
# Avnika                        0.0                0.0                 0.0
# Avnika's City                 NaN                NaN                 NaN
#
#                Airport  Airport Food Court  Airport Lounge  ...  Waterfall  \
# City                                                        ...
# Avnika             0.0                 0.0             0.0  ...        0.0
# Avnika             0.0                 0.0             0.0  ...        0.0
# Avnika             0.0                 0.0             0.0  ...        0.0
# Avnika             0.0                 0.0             0.0  ...        0.0
# Avnika             0.0                 0.0             0.0  ...        0.0
# ...                ...                 ...             ...  ...        ...
# Avnika             0.0                 0.0             0.0  ...        0.0
# Avnika             0.0                 0.0             0.0  ...        0.0
# Avnika             0.0                 0.0             0.0  ...        0.0
# Avnika             0.0                 0.0             0.0  ...        0.0
# Avnika's City      NaN                 NaN             NaN  ...        NaN
#
#                Waterfront  Whisky Bar  Wine Bar  Wine Shop  Winery  \
# City
# Avnika                0.0         0.0  0.013514   0.000000    0.00
# Avnika                0.0         0.0  0.010000   0.000000    0.01
# Avnika                0.0         0.0  0.000000   0.020000    0.00
# Avnika                0.0         0.0  0.007692   0.011538    0.00
# Avnika                0.0         0.0  0.000000   0.010000    0.00
# ...                   ...         ...       ...        ...     ...
# Avnika                0.0         0.0  0.000000   0.000000    0.00
# Avnika                0.0         0.0  0.000000   0.000000    0.00
# Avnika                0.0         0.0  0.020000   0.000000    0.00
# Avnika                0.0         0.0  0.000000   0.000000    0.00
# Avnika's City         NaN         NaN       NaN        NaN     NaN
#
#                Wings Joint  Women's Store  Yoga Studio       Zoo
# City
# Avnika            0.027027            0.0         0.00  0.013514
# Avnika            0.020000            0.0         0.00  0.010000
# Avnika            0.000000            0.0         0.01  0.000000
# Avnika            0.003846            0.0         0.00  0.003846
# Avnika            0.000000            0.0         0.00  0.010000
# ...                    ...            ...          ...       ...
# Avnika            0.000000            0.0         0.00  0.000000
# Avnika            0.000000            0.0         0.00  0.000000
# Avnika            0.010000            0.0         0.00  0.000000
# Avnika            0.010000            0.0         0.00  0.000000
# Avnika's City          NaN            NaN          NaN       NaN
#
# [653 rows x 514 columns]

# %%
user_reftable.loc[user_row, imp[0]]= 0.23
user_reftable.loc[user_row, imp[1]]= 0.20
user_reftable.loc[user_row, imp[2]]=0.18
user_reftable.loc[user_row, imp[3]]=0.15
user_reftable.loc[user_row, imp[4]]=0.13
user_reftable.loc[user_row, imp[5]]=0.10
user_reftable.loc[user_row, imp[6]]=0.08
user_reftable.loc[user_row, imp[7]]=0.05
user_reftable.loc[user_row, imp[8]]=0.03
user_reftable.loc[user_row, imp[9]]=0.00

user_reftable.replace(np.nan, 0.0, inplace= True)
user_reftable[user_row]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-131-a9036d3d930c> in <module>
#       1 user_reftable.set_index('City', inplace=True)
# ----> 2 user_reftable.loc[user_row, imp[0]]= 0.23
#       3 user_reftable.loc[user_row, imp[1]]= 0.20
#       4 user_reftable.loc[user_row, imp[2]]=0.18
#       5 user_reftable.loc[user_row, imp[3]]=0.15
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     203             key = com.apply_if_callable(key, self.obj)
#     204         indexer = self._get_setitem_indexer(key)
# --> 205         self._setitem_with_indexer(indexer, value)
#     206
#     207     def _validate_key(self, key, axis: int):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value)
#     389                     index = self.obj._get_axis(i)
#     390                     labels = index.insert(len(index), key)
# --> 391                     self.obj._data = self.obj.reindex(labels, axis=i)._data
#     392                     self.obj._maybe_update_cacher(clear=True)
#     393                     self.obj._is_copy = None
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     219         @wraps(func)
#     220         def wrapper(*args, **kwargs):
# --> 221             return func(*args, **kwargs)
#     222
#     223         kind = inspect.Parameter.POSITIONAL_OR_KEYWORD
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in reindex(self, *args, **kwargs)
#    3959         kwargs.pop("axis", None)
#    3960         kwargs.pop("labels", None)
# -> 3961         return super().reindex(**kwargs)
#    3962
#    3963     def drop(
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in reindex(self, *args, **kwargs)
#    4512         # perform the reindex on the axes
#    4513         return self._reindex_axes(
# -> 4514             axes, level, limit, tolerance, method, fill_value, copy
#    4515         ).__finalize__(self)
#    4516
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    3847         if index is not None:
#    3848             frame = frame._reindex_index(
# -> 3849                 index, method, copy, level, fill_value, limit, tolerance
#    3850             )
#    3851
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _reindex_index(self, new_index, method, copy, level, fill_value, limit, tolerance)
#    3863     ):
#    3864         new_index, indexer = self.index.reindex(
# -> 3865             new_index, method=method, level=level, limit=limit, tolerance=tolerance
#    3866         )
#    3867         return self._reindex_with_indexers(
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in reindex(self, target, method, level, limit, tolerance)
#    3414                             "with a method or limit"
#    3415                         )
# -> 3416                     indexer, missing = self.get_indexer_non_unique(target)
#    3417
#    3418         if preserve_names and target.nlevels == 1 and target.name != self.name:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_indexer_non_unique(self, target)
#    4799             tgt_values = target._ndarray_values
#    4800
# -> 4801         indexer, missing = self._engine.get_indexer_non_unique(tgt_values)
#    4802         return ensure_platform_int(indexer), missing
#    4803
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_indexer_non_unique()
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
np.linspace(0,.23,10)
# Out:
# array([0.        , 0.02555556, 0.05111111, 0.07666667, 0.10222222,
#        0.12777778, 0.15333333, 0.17888889, 0.20444444, 0.23      ])

# %%
user_reftable.iloc[user_row]
# Out:
# City                    Avnika's City
# Zoo Exhibit                         0
# ATM                                 0
# Accessories Store                   0
# Adult Boutique                      0
#                             ...
# (652, Train Station)              0.1
# (652, Video Store)               0.08
# (652, Field )                    0.05
# (652, Fountain)                  0.03
# (652, Coffee Shop)                  0
# Name: 652, Length: 525, dtype: object
